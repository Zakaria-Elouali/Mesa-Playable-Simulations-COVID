# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.time import SimultaneousActivation
from mesa.space import MultiGrid
from mesa.space import SingleGrid
from mesa.datacollection import DataCollector
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.UserParam import Slider

# %%
import psutil
def kill_process_using_port(port):
    for proc in psutil.process_iter(['pid', 'name', 'connections']):
        for conn in proc.info['connections']:
            if conn.laddr.port == port:
                try:
                    print(f"Killing process {proc.info['pid']} ({proc.info['name']}) using port {port}")
                    proc.terminate()
                    proc.wait()
                    return
                except (psutil.NoSuchProcess, psutil.AccessDenied):
                    print(f"Could not terminate process {proc.info['pid']} ({proc.info['name']})")

port = 8524
kill_process_using_port(port)

# %%
import random

# Define the state constants
SUSCEPTIBLE = 0
ASYMPTOMATIC = 1  # Infected but no symptoms yet (incubation period)
SYMPTOMATIC = 2   # Infected with symptoms
RECOVERED = 3

class Person(Agent):
    """An agent representing a single person in the grid."""
    def __init__(self, pos, model):
        super().__init__(pos, model)
        self.pos = pos
        self.state = SUSCEPTIBLE
        self.incubation_time = 0
        self.symptom_time = 0
        self.next_state = self.state

    def step(self):
        if self.state == ASYMPTOMATIC:
            neighbors = self.model.grid.get_neighbors(self.pos, moore=False, include_center=False)
            for neighbor in neighbors:
                if neighbor.state == SUSCEPTIBLE and random.random() < self.model.transmission_rate:
                    neighbor.next_state = ASYMPTOMATIC
                    neighbor.incubation_time = self.model.incubation_period
            self.incubation_time -= 1

            if self.incubation_time <= 0:
                self.next_state = SYMPTOMATIC
                self.symptom_time = self.model.symptom_period

        elif self.state == SYMPTOMATIC:
            self.symptom_time -= 1

            if self.symptom_time <= 0:
                self.next_state = RECOVERED

    def advance(self):
        self.state = self.next_state

# %%
class DiseaseModel(Model):
    """A model with some number of agents."""
    def __init__(self, width, height, density, initial_infected, incubation_period, symptom_period,transmission_rate):
        super().__init__()
        self.num_agents = width * height
        self.grid = SingleGrid(width, height, torus=True)
        self.schedule = SimultaneousActivation(self)
        self.incubation_period = incubation_period
        self.symptom_period = symptom_period
        self.transmission_rate = transmission_rate

        for content, (x, y) in self.grid.coord_iter():
            agent = Person((x, y), self)
            self.grid.place_agent(agent, (x, y))
            self.schedule.add(agent)

        self.running = True
        
        center_x, center_y = width // 2, height // 2
        center_agent = self.grid.get_cell_list_contents([(center_x, center_y)])[0]
        center_agent.state = ASYMPTOMATIC
        center_agent.incubation_time = incubation_period

    def step(self):
        self.schedule.step()

# %%
def agent_portrayal(agent):
    portrayal = {"Shape": "rect", "w": 1, "h": 1,"Filled": "True",
                 "Layer": 0}
    if agent.state == SUSCEPTIBLE:
        portrayal["Color"] = "white"
    elif agent.state == ASYMPTOMATIC:
        portrayal["Color"] = "pink"
    elif agent.state == SYMPTOMATIC:
        portrayal["Color"] = "red"
    elif agent.state == RECOVERED:
        portrayal["Color"] = "gray"
    return portrayal

grid = CanvasGrid(agent_portrayal, 50, 50, 500, 500)
# Now you can launch your server
server = ModularServer(DiseaseModel,
                       [grid],
                       "Disease Model (Probabilistic Infection)",
                       {"width": 50,
                        "height": 50,
                        "density": Slider("Initial infected", 0.8, 0.1, 1.0, 0.1),
                        "initial_infected": Slider("Infection rate", 1, 0, 10, 1),
                        "incubation_period": Slider("Incubation period", 2, 0, 10, 1),
                        "symptom_period": Slider('Symptom Period', 8, 1, 20, 1),
                        "transmission_rate": Slider("Transmission rate", 0.5, 0.0, 1.0, 0.01)
                       })
server.port = port
server.launch()
# Out:
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 6) is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 9) is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 10) is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 11) is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 12) is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 13) is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 14) is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 15) is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 16) is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 17) is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 18) is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 19) is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 20) is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 21) is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 22) is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 23) is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 24) is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 25) is being placed with
# place_agent() despite already having the position (0, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 26) is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 27) is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 28) is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 29) is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 30) is being placed with
# place_agent() despite already having the position (0, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 31) is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 32) is being placed with
# place_agent() despite already having the position (0, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 33) is being placed with
# place_agent() despite already having the position (0, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 34) is being placed with
# place_agent() despite already having the position (0, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 35) is being placed with
# place_agent() despite already having the position (0, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 36) is being placed with
# place_agent() despite already having the position (0, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 37) is being placed with
# place_agent() despite already having the position (0, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 38) is being placed with
# place_agent() despite already having the position (0, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 39) is being placed with
# place_agent() despite already having the position (0, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 40) is being placed with
# place_agent() despite already having the position (0, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 41) is being placed with
# place_agent() despite already having the position (0, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 42) is being placed with
# place_agent() despite already having the position (0, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 43) is being placed with
# place_agent() despite already having the position (0, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 44) is being placed with
# place_agent() despite already having the position (0, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 45) is being placed with
# place_agent() despite already having the position (0, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 46) is being placed with
# place_agent() despite already having the position (0, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 47) is being placed with
# place_agent() despite already having the position (0, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 48) is being placed with
# place_agent() despite already having the position (0, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (0, 49) is being placed with
# place_agent() despite already having the position (0, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 4) is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 6) is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 9) is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 10) is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 11) is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 12) is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 13) is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 14) is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 15) is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 16) is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 17) is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 18) is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 19) is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 20) is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 21) is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 22) is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 23) is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 24) is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 25) is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 26) is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 27) is being placed with
# place_agent() despite already having the position (1, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 28) is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 29) is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 30) is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 31) is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 32) is being placed with
# place_agent() despite already having the position (1, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 33) is being placed with
# place_agent() despite already having the position (1, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 34) is being placed with
# place_agent() despite already having the position (1, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 35) is being placed with
# place_agent() despite already having the position (1, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 36) is being placed with
# place_agent() despite already having the position (1, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 37) is being placed with
# place_agent() despite already having the position (1, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 38) is being placed with
# place_agent() despite already having the position (1, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 39) is being placed with
# place_agent() despite already having the position (1, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 40) is being placed with
# place_agent() despite already having the position (1, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 41) is being placed with
# place_agent() despite already having the position (1, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 42) is being placed with
# place_agent() despite already having the position (1, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 43) is being placed with
# place_agent() despite already having the position (1, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 44) is being placed with
# place_agent() despite already having the position (1, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 45) is being placed with
# place_agent() despite already having the position (1, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 46) is being placed with
# place_agent() despite already having the position (1, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 47) is being placed with
# place_agent() despite already having the position (1, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 48) is being placed with
# place_agent() despite already having the position (1, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (1, 49) is being placed with
# place_agent() despite already having the position (1, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 3) is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 6) is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 9) is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 10) is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 11) is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 12) is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 13) is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 14) is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 15) is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 16) is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 17) is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 18) is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 19) is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 20) is being placed with
# place_agent() despite already having the position (2, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 21) is being placed with
# place_agent() despite already having the position (2, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 22) is being placed with
# place_agent() despite already having the position (2, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 23) is being placed with
# place_agent() despite already having the position (2, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 24) is being placed with
# place_agent() despite already having the position (2, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 25) is being placed with
# place_agent() despite already having the position (2, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 26) is being placed with
# place_agent() despite already having the position (2, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 27) is being placed with
# place_agent() despite already having the position (2, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 28) is being placed with
# place_agent() despite already having the position (2, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 29) is being placed with
# place_agent() despite already having the position (2, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 30) is being placed with
# place_agent() despite already having the position (2, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 31) is being placed with
# place_agent() despite already having the position (2, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 32) is being placed with
# place_agent() despite already having the position (2, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 33) is being placed with
# place_agent() despite already having the position (2, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 34) is being placed with
# place_agent() despite already having the position (2, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 35) is being placed with
# place_agent() despite already having the position (2, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 36) is being placed with
# place_agent() despite already having the position (2, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 37) is being placed with
# place_agent() despite already having the position (2, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 38) is being placed with
# place_agent() despite already having the position (2, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 39) is being placed with
# place_agent() despite already having the position (2, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 40) is being placed with
# place_agent() despite already having the position (2, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 41) is being placed with
# place_agent() despite already having the position (2, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 42) is being placed with
# place_agent() despite already having the position (2, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 43) is being placed with
# place_agent() despite already having the position (2, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 44) is being placed with
# place_agent() despite already having the position (2, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 45) is being placed with
# place_agent() despite already having the position (2, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 46) is being placed with
# place_agent() despite already having the position (2, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 47) is being placed with
# place_agent() despite already having the position (2, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (2, 48) is being placed with
# place_agent() despite already having the position (2, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# ...
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 5) is being placed with
# place_agent() despite already having the position (49, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 6) is being placed with
# place_agent() despite already having the position (49, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 7) is being placed with
# place_agent() despite already having the position (49, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 8) is being placed with
# place_agent() despite already having the position (49, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 9) is being placed with
# place_agent() despite already having the position (49, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 10) is being placed with
# place_agent() despite already having the position (49, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 11) is being placed with
# place_agent() despite already having the position (49, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 12) is being placed with
# place_agent() despite already having the position (49, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 13) is being placed with
# place_agent() despite already having the position (49, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 14) is being placed with
# place_agent() despite already having the position (49, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 15) is being placed with
# place_agent() despite already having the position (49, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 16) is being placed with
# place_agent() despite already having the position (49, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 17) is being placed with
# place_agent() despite already having the position (49, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 18) is being placed with
# place_agent() despite already having the position (49, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 19) is being placed with
# place_agent() despite already having the position (49, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 20) is being placed with
# place_agent() despite already having the position (49, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 21) is being placed with
# place_agent() despite already having the position (49, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 22) is being placed with
# place_agent() despite already having the position (49, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 23) is being placed with
# place_agent() despite already having the position (49, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 24) is being placed with
# place_agent() despite already having the position (49, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 25) is being placed with
# place_agent() despite already having the position (49, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 26) is being placed with
# place_agent() despite already having the position (49, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 27) is being placed with
# place_agent() despite already having the position (49, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 28) is being placed with
# place_agent() despite already having the position (49, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 29) is being placed with
# place_agent() despite already having the position (49, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 30) is being placed with
# place_agent() despite already having the position (49, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 31) is being placed with
# place_agent() despite already having the position (49, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 32) is being placed with
# place_agent() despite already having the position (49, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 33) is being placed with
# place_agent() despite already having the position (49, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 34) is being placed with
# place_agent() despite already having the position (49, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 35) is being placed with
# place_agent() despite already having the position (49, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 36) is being placed with
# place_agent() despite already having the position (49, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 37) is being placed with
# place_agent() despite already having the position (49, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 38) is being placed with
# place_agent() despite already having the position (49, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 39) is being placed with
# place_agent() despite already having the position (49, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 40) is being placed with
# place_agent() despite already having the position (49, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 41) is being placed with
# place_agent() despite already having the position (49, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 42) is being placed with
# place_agent() despite already having the position (49, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 43) is being placed with
# place_agent() despite already having the position (49, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 44) is being placed with
# place_agent() despite already having the position (49, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 45) is being placed with
# place_agent() despite already having the position (49, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 46) is being placed with
# place_agent() despite already having the position (49, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 47) is being placed with
# place_agent() despite already having the position (49, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 48) is being placed with
# place_agent() despite already having the position (49, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_19932\1610533763.py:14: UserWarning: Agent (49, 49) is being placed with
# place_agent() despite already having the position (49, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# Interface starting at http://127.0.0.1:8524
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 28
#      16 server = ModularServer(DiseaseModel,
#      17                        [grid],
#      18                        "Disease Model (Probabilistic Infection)",
#    (...)
#      25                         "transmission_rate": Slider("Transmission rate", 0.5, 0.0, 1.0, 0.01)
#      26                        })
#      27 server.port = port
# ---> 28 server.launch()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mesa_viz_tornado\ModularVisualization.py:407, in ModularServer.launch(self, port, open_browser)
#     405 tornado.autoreload.start()
#     406 try:
# --> 407     tornado.ioloop.IOLoop.current().start()
#     408 except KeyboardInterrupt:
#     409     tornado.ioloop.IOLoop.current().stop()
#
# File ~\.conda\envs\Study\Lib\site-packages\tornado\platform\asyncio.py:195, in BaseAsyncIOLoop.start(self)
#     194 def start(self) -> None:
# --> 195     self.asyncio_loop.run_forever()
#
# File ~\.conda\envs\Study\Lib\asyncio\windows_events.py:319, in ProactorEventLoop.run_forever(self)
#     317 def run_forever(self):
#     318     try:
# --> 319         assert self._self_reading_future is None
#     320         self.call_soon(self._loop_self_reading)
#     321         super().run_forever()
#
# AssertionError:
