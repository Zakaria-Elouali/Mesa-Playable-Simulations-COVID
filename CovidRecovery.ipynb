# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.time import SimultaneousActivation
from mesa.space import MultiGrid
from mesa.space import SingleGrid
from mesa.datacollection import DataCollector
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.UserParam import Slider

# %%
import psutil
def kill_process_using_port(port):
    for proc in psutil.process_iter(['pid', 'name', 'connections']):
        for conn in proc.info['connections']:
            if conn.laddr.port == port:
                try:
                    print(f"Killing process {proc.info['pid']} ({proc.info['name']}) using port {port}")
                    proc.terminate()
                    proc.wait()
                    return
                except (psutil.NoSuchProcess, psutil.AccessDenied):
                    print(f"Could not terminate process {proc.info['pid']} ({proc.info['name']})")

port = 8522
kill_process_using_port(port)

# %%
# Define the state constants
SUSCEPTIBLE = 0
INFECTED = 1
RECOVERED = 2

class Person(Agent):
    """An agent representing a single person in the grid."""
    def __init__(self, pos, model):
        super().__init__(pos, model)
        self.pos = pos
        self.state = SUSCEPTIBLE
        self.incubation_time = 0
        self.next_state = self.state

    def step(self):
        if self.state == INFECTED:
            self.incubation_time -= 1
            
            if self.incubation_time <= 0:
                self.next_state = RECOVERED
            else:
                self.infect_neighbors() 
                
    def infect_neighbors(self):
        neighbors = self.model.grid.get_neighbors(self.pos, False)
        for neighbor in neighbors:
            if neighbor.state == SUSCEPTIBLE:
                neighbor.next_state = INFECTED
                neighbor.incubation_time = self.model.incubation_period

    def advance(self):
        self.state = self.next_state

# %%
class DiseaseModel(Model):
    """A model with some number of agents."""
    def __init__(self, width, height, density=0.8, initial_infected=1, incubation_period=2):
        super().__init__()
        self.num_agents = width * height
        self.grid = SingleGrid(width, height, torus=True)
        self.schedule = SimultaneousActivation(self)
        self.incubation_period = incubation_period

             # Create agents
        for content, (x, y) in self.grid.coord_iter():
            agent = Person((x, y), self)
            self.grid.place_agent(agent, (x, y))
            self.schedule.add(agent)

        self.running = True
        
        center_x, center_y = width // 2, height // 2
        center_agent = self.grid.get_cell_list_contents([(center_x, center_y)])[0]
        center_agent.state = INFECTED
        center_agent.incubation_time = incubation_period

        self.datacollector = DataCollector(
            agent_reporters={"State": "state"}
        )

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

# %%
# Define the visualization
def agent_portrayal(agent):
    portrayal = {"Shape": "rect",
                 "w": 1,
                 "h": 1,
                 "Filled": "True",
                 "Layer": 0
                }
    if agent.state == SUSCEPTIBLE:
        portrayal["Color"] = "white"
    elif agent.state == INFECTED:
        portrayal["Color"] = "red"
    elif agent.state == RECOVERED:
        portrayal["Color"] = "gray"
    return portrayal

grid = CanvasGrid(agent_portrayal, 9, 9, 500, 500)
# Now you can launch your server
server = ModularServer(DiseaseModel,
                       [grid],
                       "Disease Model (Recovery)",
                       {"width": 9,
                        "height": 9,
                        "density": Slider("Initial infected", 0.8, 0.1, 1.0, 0.1),
                        "initial_infected": Slider("Infection rate", 1, 0, 10, 1),
                        "incubation_period": Slider("Incubation period", 2, 0, 10, 1)
                       })
server.port = port
server.launch()
# Out:
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 6) is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 4) is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 6) is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 3) is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 6) is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 0) is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 1) is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 2) is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 3) is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 4) is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 5) is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 6) is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 7) is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (3, 8) is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 0) is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 1) is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 2) is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 3) is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 4) is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 5) is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 6) is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 7) is being placed with
# place_agent() despite already having the position (4, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (4, 8) is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 0) is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 1) is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 2) is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 3) is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 4) is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 5) is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 6) is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 7) is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (5, 8) is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 0) is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 1) is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 2) is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 3) is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 4) is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 5) is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 6) is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 7) is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (6, 8) is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 0) is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 1) is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 2) is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 3) is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 4) is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 5) is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 6) is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 7) is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (7, 8) is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 0) is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 1) is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 2) is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 3) is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 4) is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 5) is being placed with
# place_agent() despite already having the position (8, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 6) is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 7) is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# C:\Users\asust\AppData\Local\Temp\ipykernel_16896\23057915.py:13: UserWarning: Agent (8, 8) is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# Interface starting at http://127.0.0.1:8522
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 29
#      19 server = ModularServer(DiseaseModel,
#      20                        [grid],
#      21                        "Disease Model (Recovery)",
#    (...)
#      26                         "incubation_period": Slider("Incubation period", 2, 0, 10, 1)
#      27                        })
#      28 server.port = port
# ---> 29 server.launch()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mesa_viz_tornado\ModularVisualization.py:407, in ModularServer.launch(self, port, open_browser)
#     405 tornado.autoreload.start()
#     406 try:
# --> 407     tornado.ioloop.IOLoop.current().start()
#     408 except KeyboardInterrupt:
#     409     tornado.ioloop.IOLoop.current().stop()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:195, in BaseAsyncIOLoop.start(self)
#     194 def start(self) -> None:
# --> 195     self.asyncio_loop.run_forever()
#
# File C:\ProgramData\anaconda3\Lib\asyncio\windows_events.py:319, in ProactorEventLoop.run_forever(self)
#     317 def run_forever(self):
#     318     try:
# --> 319         assert self._self_reading_future is None
#     320         self.call_soon(self._loop_self_reading)
#     321         super().run_forever()
#
# AssertionError:
